# %%
x= NULL
x[1]= 0

for(i in 2:1000){
x[i] = x[i-1] + rnorm(1)
}
print(x)
# Out:
#    [1]   0.000000000   0.294755517   0.162288831   1.120904946  -0.885551425
#    [6]  -1.632244214  -2.940453520  -1.689345990  -0.751474052  -1.658955871
#   [11]  -1.071351399  -0.372809703   0.992959544   1.077649328   1.288645399
#   [16]   1.916192647   2.867827770   2.911858648   2.041878862   2.029286283
#   [21]   1.967267187   1.904177361   2.030146786   1.597675112   1.533627781
#   [26]   3.540167272   2.425113556   1.340877557   3.063065271   3.090437172
#   [31]   2.968030834   3.906408401   5.220539736   5.276803513   4.766991313
#   [36]   4.529666813   4.270842365   3.299368700   3.189665441   3.007541217
#   [41]   3.872672669   3.827178202   4.569322010   3.631825606   4.753024108
#   [46]   4.982056116   2.582659584   3.083038228   3.148504023   4.355254887
#   [51]   5.166168407   6.178835422   7.150796759   8.120964866   8.671765498
#   [56]   9.463064344   8.827793020   8.123567488   7.838743232   6.022289975
# ...

# %%
random_walk = ts(x)
plot(random_walk, )
